# %% [markdown]
# # 1.Preparing Data

# %%
import pandas as pd

# %%
import numpy as np

# %%
sheet_1 = pd.read_csv("1.csv",encoding='gb18030')
# Out:
# /Users/duli/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sheet_2 = pd.read_csv("2.csv",encoding='gb18030')
# Out:
# /Users/duli/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
excel3 = pd.ExcelFile('3.xlsx')
sheet_3 = pd.read_excel(excel3)

# %%
excel4 = pd.ExcelFile('4.xlsx')
sheet_4 = pd.read_excel(excel4)

# %% [markdown]
# # Q1

# %% [markdown]
# ### Sheet 1

# %%
import time

# %%
sheet_1['create_dt'] = sheet_1['create_dt'].astype('datetime64')

# %%
time_revised_sheet_1 = sheet_1[(sheet_1['create_dt']>np.datetime64('2016-11-30'))&((sheet_1['create_dt']<np.datetime64('2019-01-02')))]

# %%
vaild_data_Sheet1 = time_revised_sheet_1[time_revised_sheet_1["is_finished"] == 1]

# %%
non_vaild_data_sheet1 = time_revised_sheet_1[time_revised_sheet_1["is_finished"] == 0]

# %%
Q1_sheet1 = vaild_data_Sheet1[['sku_cnt','sku_prc','sku_sale_prc','sku_cost_prc','upc_code']]

# %%
Q1_sheet1['upc_code'] = Q1_sheet1.apply(lambda x:x['sku_cnt']*x['sku_sale_prc'],axis=1)
# Out:
# /Users/duli/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Q1_sheet_1_sales = Q1_sheet1['upc_code'].sum()

# %%
promotion_profit_sheet1 = 0

# %%
Q1_sheet1 = vaild_data_Sheet1[['sku_cnt','sku_prc','sku_sale_prc','sku_cost_prc','upc_code']]

# %%
Q1_sheet1['upc_code'] = Q1_sheet1.apply(lambda x:x['sku_sale_prc']-x['sku_sale_prc']/1.3,axis=1)
# Out:
# /Users/duli/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
non_promotion_profit_sheet1 = Q1_sheet1['upc_code'].sum()

# %%
non_promotion_profit_sheet1
# Out:
# 1872254.6215384617

# %%
Q1_sheet1 = vaild_data_Sheet1[['sku_cnt','sku_prc','sku_sale_prc','sku_cost_prc','upc_code']]

# %%
promotion_cost_sheet1 = Q1_sheet1[Q1_sheet1['sku_cost_prc']!=0]['sku_cost_prc'].sum()

# %%
promotion_cost_sheet1
# Out:
# 3081178.8800000004

# %%
Q1_sheet1['upc_code'] = Q1_sheet1.apply(lambda x:x['sku_sale_prc']/1.3,axis=1)
# Out:
# /Users/duli/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
non_promotion_cost_sheet1 = Q1_sheet1['upc_code'].sum()

# %%
non_promotion_cost_sheet1
# Out:
# 6240848.738461537

# %% [markdown]
# ## Sheet2

# %%
sheet_2['create_dt'] = sheet_2['create_dt'].astype('datetime64')

# %%
time_revised_sheet_2 = sheet_2[(sheet_2['create_dt']>np.datetime64('2016-11-30'))&((sheet_2['create_dt']<np.datetime64('2019-01-02')))]

# %%
vaild_data_Sheet2 = time_revised_sheet_2[time_revised_sheet_2["is_finished"] == 1]

# %%
Q1_sheet2 = vaild_data_Sheet2[['sku_cnt','sku_prc','sku_sale_prc','sku_cost_prc','upc_code']]

# %%
Q1_sheet2['upc_code'] = Q1_sheet2.apply(lambda x:x['sku_cnt']*x['sku_sale_prc'],axis=1)
# Out:
# /Users/duli/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Q1_sheet_2_sales = Q1_sheet2['upc_code'].sum()

# %%
promotion_profit_sheet2 = 0

# %%
Q1_sheet2 = vaild_data_Sheet2[['sku_cnt','sku_prc','sku_sale_prc','sku_cost_prc','upc_code']]

# %%
Q1_sheet2['upc_code'] = Q1_sheet2.apply(lambda x:x['sku_sale_prc']-x['sku_sale_prc']/1.3,axis=1)
# Out:
# /Users/duli/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
non_promotion_profit_sheet2 = Q1_sheet2['upc_code'].sum()

# %%
Q1_sheet2 = vaild_data_Sheet2[['sku_cnt','sku_prc','sku_sale_prc','sku_cost_prc','upc_code']]
promotion_cost_sheet2 = Q1_sheet2[Q1_sheet2['sku_cost_prc']!=0]['sku_cost_prc'].sum()
Q1_sheet2['upc_code'] = Q1_sheet2.apply(lambda x:x['sku_sale_prc']/1.3,axis=1)
non_promotion_cost_sheet2 = Q1_sheet2['upc_code'].sum()
# Out:
# /Users/duli/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## Sum up

# %%
Q1_sales = Q1_sheet_1_sales + Q1_sheet_2_sales

# %%
Q1_sales
# Out:
# 19753871.58

# %%
Q1_profit_rate = ((promotion_profit_sheet1+promotion_profit_sheet2+non_promotion_profit_sheet1+non_promotion_profit_sheet2)/(promotion_cost_sheet1+promotion_cost_sheet2+non_promotion_cost_sheet1+non_promotion_cost_sheet2))

# %%
Q1_profit_rate
# Out:
# 0.1999910133337423

# %% [markdown]
# # Q2

# %%
RCDS_Weight = np.array([(1, 1/7, 1/2),(7, 1, 5),(2, 1/5, 1)])

# %%
W_ = {}
W_sum = 0
for i in range(RCDS_Weight.shape[0]):
    name_matrix = ['Wc_', 'Wd_', 'Ws_']
    temp = 1
    for j in range(RCDS_Weight.shape[1]):
        temp = RCDS_Weight[i, j]*temp
    W_[name_matrix[i]] = np.power(temp,1/3)
    W_sum += W_[name_matrix[i]]

# %%
for i in W_:
    W_[i] = round(W_[i]/W_sum,3)

# %%
W_sum
# Out:
# 4.4227858765997885

# %%
W_
# Out:
# {'Wc_': 0.094, 'Wd_': 0.74, 'Ws_': 0.167}

# %%
W_rearrange = []

# %%
W_rearrange.append(W_['Wc_'])

# %%
W_rearrange.append(W_['Wd_'])

# %%
W_rearrange.append(W_['Ws_'])

# %%
l_dic = []
sum_ = 0
for i in range(3):
    count = 0
    for j in range(3):
        count = count + W_rearrange[j]*RCDS_Weight[i][j]
    
    l_dic.append(count)
    sum_ = sum_ + count
    print(count)
# Out:
# 0.2832142857142857
# 2.233
# 0.503

# %%
sum_
# Out:
# 3.019214285714286

# %%
CI = (sum_ - 3)/2

# %%
CI
# Out:
# 0.009607142857142925

# %%
RCDS_Weight
# Out:
# array([[1.        , 0.14285714, 0.5       ],
#        [7.        , 1.        , 5.        ],
#        [2.        , 0.2       , 1.        ]])

# %%
RI = 0.58

# %%
CR = CI / RI

# %%
CR
# Out:
# 0.016564039408867113

# %%
(sheet_3['end_time']-sheet_3['begin_time']).max()
# Out:
# Timedelta('375 days 00:00:00')

# %%
merged_test = pd.merge(sheet_1,sheet_3,on='sku_id')

# %%
a = sheet_1[sheet_1['create_dt']==np.datetime64('2017-03-07')]

# %%
b = a[a['sku_cost_prc']!=0]

# %%
len(sheet_3['sku_id'].unique())
# Out:
# 3958

# %%
len(sheet_1['sku_id'].unique())
# Out:
# 6257

# %%
len(sheet_4['sku_id'].unique())
# Out:
# 6570

# %%
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-21
# 2018-07-22
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-28
# 2018-07-29
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-04
# 2018-08-05
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-11
# 2018-08-12
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-18
# 2018-08-19
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-25
# 2018-08-26
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-01
# 2018-09-02
# 2018-09-03
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-08
# 2018-09-09
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-15
# 2018-09-16
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-22
# 2018-09-23
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-09-29
# 2018-09-30
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-06
# 2018-10-07
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-13
# 2018-10-14
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-20
# 2018-10-21
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-27
# 2018-10-28
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-03
# 2018-11-04
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-10
# 2018-11-11
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-17
# 2018-11-18
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-22
# 2018-11-23
# 2018-11-24
# 2018-11-25
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-01
# 2018-12-02
# 2018-12-03
# 2018-12-04
# 2018-12-05
# 2018-12-06
# 2018-12-07
# 2018-12-08
# 2018-12-09
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-15
# 2018-12-16
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-22
# 2018-12-23
# 2018-12-24
# 2018-12-25
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-29
# 2018-12-30
# 2018-12-31
# 2019-01-01
# 2019-01-02
# 2019-01-03

# %%
temp_dic = {}
for i in range(100):
    
    test1 = Discount_info_per_day[np.datetime64('2017-09-11')+i]
    test2 = sheet_1[sheet_1['create_dt']==np.datetime64('2017-09-11')+i]
    c = pd.merge(test1,test2,on='sku_id')
    temp_dic[i] = c

# %%
temp_dic[50]
# Out:
#           id  promotion_info_id promotion_no      sku_id           sku_name_x  \
# 0  172423110            7742868           \N  2010573961  m&m‘s 花生牛奶巧克力豆 160g
# 1  172423109            7742868           \N  2010576731    m&m‘s 牛奶巧克力豆 160g
# 2  172423109            7742868           \N  2010576731    m&m‘s 牛奶巧克力豆 160g
# 3  172423109            7742868           \N  2010576731    m&m‘s 牛奶巧克力豆 160g
# 4  172423109            7742868           \N  2010576731    m&m‘s 牛奶巧克力豆 160g
#
#    promotion_price          begin_time            end_time  limit_count  \
# 0             1290 2017-10-27 09:00:00 2017-10-31 20:00:00          500
# 1             1290 2017-10-27 09:00:00 2017-10-31 20:00:00          500
# 2             1290 2017-10-27 09:00:00 2017-10-31 20:00:00          500
# 3             1290 2017-10-27 09:00:00 2017-10-31 20:00:00          500
# 4             1290 2017-10-27 09:00:00 2017-10-31 20:00:00          500
#
#    sale_count  ...  create_dt_x  create_dt_y         order_id  \
# 0           7  ...   2017-10-27   2017-10-31  726253664000122
# 1          12  ...   2017-10-27   2017-10-31  726246285000341
# 2          12  ...   2017-10-27   2017-10-31  726235725000021
# 3          12  ...   2017-10-27   2017-10-31  726243072000022
# 4          12  ...   2017-10-27   2017-10-31  726243092000322
#
#                      sku_name_y is_finished sku_cnt sku_prc  sku_sale_prc  \
# 0  【万圣节来抢糖吧】m&m‘s 花生牛奶巧克力豆 160g           0       1    16.8          16.8
# 1    【万圣节来抢糖吧】m&m‘s 牛奶巧克力豆 160g           0       1    16.8          12.9
# 2    【万圣节来抢糖吧】m&m‘s 牛奶巧克力豆 160g           1       1    16.8          12.9
# 3    【万圣节来抢糖吧】m&m‘s 牛奶巧克力豆 160g           0       1    16.8          12.9
# 4    【万圣节来抢糖吧】m&m‘s 牛奶巧克力豆 160g           1       1    16.8          12.9
#
#   sku_cost_prc       upc_code
# 0          0.0             \N
# 1         12.9             \N
# 2         12.9  6914973604360
# 3         12.9             \N
# 4         12.9  6914973604360
#
# [5 rows x 36 columns]

# %%
a = sheet_3_vaild[sheet_3_vaild['limit_count']==sheet_3_vaild['sale_count']]

# %%
a[a['limit_count']!=0]
# Out:
#              id  promotion_info_id promotion_no      sku_id  \
# 9102  191708878            8236304           \N  2008559131
#
#                sku_name  promotion_price          begin_time  \
# 9102  多力多滋 劲浓芝士味玉米片 68g              300 2017-12-22 23:00:00
#
#                 end_time  limit_count  sale_count  ...  yn  \
# 9102 2017-12-23 21:59:04            5           5  ...   0
#
#                        ts begin_state end_state cost_price allowance  \
# 9102  2017-12-23 21:59:44           0         0        480         1
#
#      business_version  promotion_type         time_id  create_dt
# 9102              120               4  20171222230000 2017-12-22
#
# [1 rows x 27 columns]

# %%
sheet_3[sheet_3['sku_id']==2010573961]
# Out:
#              id  promotion_info_id promotion_no      sku_id  \
# 7265  172423110            7742868           \N  2010573961
#
#                  sku_name  promotion_price          begin_time  \
# 7265  m&m‘s 花生牛奶巧克力豆 160g             1290 2017-10-27 09:00:00
#
#                 end_time  limit_count  sale_count  ...  yn  \
# 7265 2017-10-31 20:00:00          500           7  ...   0
#
#                        ts begin_state end_state cost_price allowance  \
# 7265  2017-10-31 20:01:05           0         0       1290         0
#
#      business_version  promotion_type         time_id  create_dt
# 7265              310               4  20171027090000 2017-10-27
#
# [1 rows x 27 columns]

# %%
d
# Out:
#         create_dt         order_id      sku_id                      sku_name  \
# 49813  2017-12-08  729526983000021  2010573961           m&m‘s 花生牛奶巧克力豆 160g
# 134257 2017-10-29  726077853000042  2010573961  【万圣节来抢糖吧】m&m‘s 花生牛奶巧克力豆 160g
# 263978 2017-10-29  726045289000021  2010573961  【万圣节来抢糖吧】m&m‘s 花生牛奶巧克力豆 160g
# 264131 2017-10-31  726253839000021  2010573961  【万圣节来抢糖吧】m&m‘s 花生牛奶巧克力豆 160g
# 521352 2017-10-28  725956288000722  2010573961  【万圣节来抢糖吧】m&m‘s 花生牛奶巧克力豆 160g
# 521488 2017-10-29  726072015000142  2010573961  【万圣节来抢糖吧】m&m‘s 花生牛奶巧克力豆 160g
#
#         is_finished  sku_cnt  sku_prc  sku_sale_prc  sku_cost_prc  \
# 49813             1        1     16.8          16.8           0.0
# 134257            1        1     16.8          12.9          12.9
# 263978            1        1     16.8          12.9          12.9
# 264131            1        1     16.8          16.8           0.0
# 521352            1        1     16.8          12.9          12.9
# 521488            1        1     16.8          12.9          12.9
#
#              upc_code
# 49813   6914973604377
# 134257  6914973604377
# 263978  6914973604377
# 264131  6914973604377
# 521352  6914973604377
# 521488  6914973604377

# %%
d =sheet_2[sheet_2['sku_id']==2010573961]

# %%
d[d['sku_cost_prc']!=0]
# Out:
#         create_dt         order_id      sku_id             sku_name  \
# 10230  2017-10-20  725275551000242  2008559131   多力多滋劲浓芝士味玉米片 68g/包
# 23857  2018-06-17  814465129000441  2008559131  多力多滋 劲浓芝士味玉米片 68g/包
# 37353  2018-10-21  825348531001541  2008559131  多力多滋 劲浓芝士味玉米片 68g/袋
# 48822  2017-07-08  716307420000442  2008559131    多力多滋 劲浓芝士味玉米片 68g
# 49266  2017-07-17  717091847000141  2008559131    多力多滋 劲浓芝士味玉米片 68g
# 53509  2017-10-20  725268298000322  2008559131   多力多滋劲浓芝士味玉米片 68g/包
# 53518  2017-10-20  725268815001221  2008559131   多力多滋劲浓芝士味玉米片 68g/包
# 66158  2018-06-09  813792498000422  2008559131  多力多滋 劲浓芝士味玉米片 68g/包
# 67059  2018-06-18  814550933000241  2008559131  多力多滋 劲浓芝士味玉米片 68g/包
# 71966  2018-08-03  818560958000022  2008559131  多力多滋 劲浓芝士味玉米片 68g/袋
#
# 200806            1        1     4.80          3.90           3.9
# 221337            1        1     5.80          4.80           4.8
# 225967            1        1     4.81          1.00           4.8
# 225991            1        1     4.81          1.00           4.8
# 230629            1        1     4.80          1.80           4.8
# 264030            1        1     5.80          4.80           4.8
# 264568            1        1     5.80          4.80           4.8
# 268691            1        1     4.81          1.00           4.8
# 273543            1        1     4.80          1.80           4.8
# 282094            1        1     4.80          3.00           4.8
# 287784            1        2     4.80          3.90           3.9
# 307815            1        1     5.80          4.80           4.8
# 312266            1        1     4.81          1.00           4.8
# 312275            1        1     4.81          1.00           4.8
# 317021            1        1     4.80          1.80           4.8
# 324821            1        1     4.80          3.00           4.8
# 355890            1        1     4.81          1.00           4.8
# 355894            1        1     4.81          1.00           4.8
# 358581            1        1     4.80          3.00           4.8
# 368069            1        1     4.80          3.00           4.8
# 368896            1        1     4.80          3.00           4.8
# 398404            1        1     4.81          1.00           4.8
# 403136            1        1     4.80          1.80           4.8
# 442029            1        1     4.81          1.00           4.8
# 455449            1        1     4.80          3.00           4.8
# 484760            1        1     4.81          1.00           4.8
# 528657            1        1     4.81          1.00           4.8
# 528662            1        1     4.81          1.00           4.8
# 528676            0        1     4.81          1.00           4.8
# 528685            1        1     4.81          1.00           4.8
# 531452            1        1     4.80          3.00           4.8
# 541626            1        1     4.80          3.00           4.8
# 572037            1        1     4.81          1.00           4.8
# 572052            1        1     4.81          1.00           4.8
# 575010            1        1     4.80          3.00           4.8
# 590340            1        1     4.80          3.90           3.9
# 591377            1        1     4.80          3.90           3.9
# 598772            1        1     4.80          2.99           4.8
#
#              upc_code
# 10230   6924743920545
# 23857   6924743920545
# 37353   6924743920545
# 48822   6924743920545
# 49266   6924743920545
# 53509   6924743920545
# 53518   6924743920545
# 66158   6924743920545
# 67059             NaN
# 71966   6924743920545
# 73362   6924743920545
# 80788   6924743920545
# 92981   6924743920545
# 123644  6924743920545
# 139919  6924743920545
# 152875  6924743920545
# 157513  6924743920545
# 178176  6924743920545
# 182115  6924743920545
# 186741  6924743920545
# 195504  6924743920545
# 200806  6924743920545
# 221337  6924743920545
# 225967  6924743920545
# 225991  6924743920545
# 230629  6924743920545
# 264030  6924743920545
# 264568  6924743920545
# 268691  6924743920545
# 273543  6924743920545
# 282094  6924743920545
# 287784  6924743920545
# 307815  6924743920545
# 312266  6924743920545
# 312275  6924743920545
# 317021  6924743920545
# 324821  6924743920545
# 355890  6924743920545
# 355894  6924743920545
# 358581  6924743920545
# 368069  6924743920545
# 368896  6924743920545
# 398404  6924743920545
# 403136  6924743920545
# 442029  6924743920545
# 455449  6924743920545
# 484760  6924743920545
# 528657  6924743920545
# 528662  6924743920545
# 528676             \N
# 528685  6924743920545
# 531452  6924743920545
# 541626  6924743920545
# 572037  6924743920545
# 572052  6924743920545
# 575010  6924743920545
# 590340    6.92474e+12
# 591377    6.92474e+12
# 598772    6.92474e+12

# %%
sheet_2[sheet_2['sku_id']==2005469176]
# Out:
#         create_dt         order_id      sku_id             sku_name  \
# 2370   2017-09-08  721669240000022  2005469176  冰泉 滴珠豆浆粉 360g（12小包）
# 261621 2017-09-07  721562489000141  2005469176  冰泉 滴珠豆浆粉 360g（12小包）
# 261657 2017-09-09  721710338000042  2005469176  冰泉 滴珠豆浆粉 360g（12小包）
# 433030 2017-09-08  721649887000041  2005469176  冰泉 滴珠豆浆粉 360g（12小包）
#
#         is_finished  sku_cnt  sku_prc  sku_sale_prc  sku_cost_prc  \
# 2370              1        1     14.5           8.8           8.8
# 261621            1        1     14.5           8.8           8.8
# 261657            1        1     14.5           8.8           8.8
# 433030            1        1     14.5           8.8           8.8
#
#              upc_code
# 2370    6901432305258
# 261621  6901432305258
# 261657  6901432305258
# 433030  6901432305258

# %%
Discount_record = sheet_1[sheet_1['create_dt']==Q2_start_time]

# %%
No_of_Goods = len(Discount_record['sku_id'].unique())

# %%
C_per_day[Q2_start_time] = No_of_Goods

# %%
Sales_count_bef = Discount_record['sku_cnt'].sum()

# %%
S_per_day[Q2_start_time] = Sales_count_bef

# %%
Discount_un = Discount_record.groupby(['sku_id']).sum()

# %%
Discount_un['is_finished'] = (Discount_un['sku_prc'] - Discount_un['sku_sale_prc'])/Discount_un['sku_prc']

# %%
if Discount_un['is_finished'].sum()!=0:
        Dis_rate = (Discount_un['is_finished'].sum())/len(Discount_un)
    else:
        Dis_rate = 0

D_per_day[Q2_start_time] = Dis_rate

# %%
Discount_record = sheet_1[sheet_1['create_dt']==Q2_start_time]

# %%
test_Q2= pd.concat([Discount_record['sku_id'],Discount_info_per_day[Q2_start_time]['sku_id']])

# %%
Class_of_goods = len(test_Q2.unique())

# %%
C_per_day[Q2_start_time] = Class_of_goods

# %%
C_per_day
# Out:
# {numpy.datetime64('2017-03-07'): 208}

# %%
Sales_count_sheet = Discount_record

# %%
Sales_count = Discount_record['sku_cnt'].sum()

# %%
S_per_day[Q2_start_time] = Sales_count

# %%
S_per_day
# Out:
# {numpy.datetime64('2017-03-07'): 380}

# %%
Dis_info_board= Discount_info_per_day[Q2_start_time]

# %%
Dis_info_un = Dis_info.groupby(['sku_id']).sum()

# %%
Dis_info_un['id'] = (Dis_info_un['pdj_price']-Dis_info_un['promotion_price'])/Dis_info_un['pdj_price']

# %%
Dis_rate_board = (Dis_info_un['id'].sum())/len(Dis_info_un)

# %%
for i in range(len(Dis_info_un)):
    
    Discount_record = Discount_record[Discount_record['sku_id']!=Dis_info_un.index[1]]

# %%
Discount_record_un = Discount_record.groupby(['sku_id']).sum()

# %%
Discount_record_un['is_finished'] = (Discount_record_un['sku_prc'] - Discount_record_un['sku_sale_prc'])/Discount_record_un['sku_prc']

# %%
Dis_rate_record = (Discount_record_un['is_finished'].sum())/len(Discount_record_un)

# %%
Dis_rate = (Dis_rate_board + Dis_rate_record)/2

# %%
Dis_rate
# Out:
# 0.2545565528143934

# %%
D_per_day[Q2_start_time] = Dis_rate
